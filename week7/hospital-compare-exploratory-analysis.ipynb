# %%
import pandas

# %%
# load the hospitals file
s3_hospitals = "s3://mids-w205-fall2016/hospital_compare/hospitals.csv"
df_hospitals = pandas.read_csv(s3_hospitals)

# load effective care file
s3_effective_care = "s3://mids-w205-fall2016/hospital_compare/effective_care.csv"
df_effective = pandas.read_csv(s3_effective_care)

# %%
# check out the data
df_hospitals.head()
# Out:
#   Provider ID                       Hospital Name  \
# 0      020024  CENTRAL PENINSULA GENERAL HOSPITAL
# 1      021301    PROVIDENCE VALDEZ MEDICAL CENTER
# 2      021302          PROVIDENCE SEWARD HOSPITAL
# 3      021304           PETERSBURG MEDICAL CENTER
# 4      021305             WRANGELL MEDICAL CENTER
#
#                           Address        City State  ZIP Code County Name  \
# 0              250 HOSPITAL PLACE    SOLDOTNA    AK     99669         NaN
# 1                      PO BOX 550      VALDEZ    AK     99686         NaN
# 2    417 FIRST AVENUE, PO BOX 365      SEWARD    AK     99664         NaN
# 3                      PO BOX 589  PETERSBURG    AK     99833         NaN
# 4  310 BENNETT STREET PO BOX 1081    WRANGELL    AK     99929         NaN
#
#    Phone Number              Hospital Type            Hospital Ownership  \
# 0    9072624404       Acute Care Hospitals  Voluntary non-profit - Other
# ...

# %%
# look at the state breakdown
df_hospitals.groupby('State').agg({'Provider ID':len})
# Out:
#        Provider ID
# State
# AK              21
# AL              91
# AR              77
# AS               1
# AZ              79
# CA             346
# CO              79
# CT              31
# DC               9
# DE               7
# FL             189
# GA             133
# GU               1
# HI              18
# IA             118
# ID              42
# IL             181
# IN             125
# KS             133
# KY              95
# LA             119
# MA              65
# MD              47
# ME              35
# MI             137
# MN             132
# MO             109
# MP               1
# MS              99
# MT              58
# NC             111
# ND              45
# NE              91
# NH              26
# NJ              65
# NM              42
# NV              36
# NY             181
# OH             170
# OK             127
# OR              61
# PA             174
# PR              52
# RI              12
# SC              63
# SD              54
# ...

# %%
# look at the type breakdown
df_hospitals.groupby('Hospital Type').agg({'Provider ID':len})
# Out:
#                                       Provider ID
# Hospital Type
# ACUTE CARE - VETERANS ADMINISTRATION          129
# Acute Care Hospitals                         3415
# Childrens                                      22
# Critical Access Hospitals                    1258

# %%
# look at the emergency room breakdown
df_hospitals.groupby('Emergency Services').agg({'Provider ID':len})
# Out:
#                     Provider ID
# Emergency Services
# No                          373
# Yes                        4451

# %%
# look at the effective care data
df_effective.head()
# Out:
#   Provider ID                     Hospital Name                 Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State  ZIP Code County Name  Phone Number  \
# 0  DOTHAN    AL     36301     HOUSTON    3347938701
# 1  DOTHAN    AL     36301     HOUSTON    3347938701
# 2  DOTHAN    AL     36301     HOUSTON    3347938701
# 3  DOTHAN    AL     36301     HOUSTON    3347938701
# 4  DOTHAN    AL     36301     HOUSTON    3347938701
#
#                     Condition Measure ID  \
# 0  Heart Attack or Chest Pain     AMI_10
# 1  Heart Attack or Chest Pain      AMI_2
# 2  Heart Attack or Chest Pain     AMI_7a
# 3  Heart Attack or Chest Pain     AMI_8a
# ...

# %%
df_effective.score2 = pandas.to_numeric(df_effective.Score, errors = 'coerce')

# %%
score_filter = df_effective.score2 < 100
df_effective[score_filter]
# Out:
#        Provider ID                             Hospital Name  \
# 0           010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 1           010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 3           010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 5           010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 7           010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 9           010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 10          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 11          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 15          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 16          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 17          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 24          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 25          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 26          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# ...

# %%
df_effective.groupby('Provider ID').agg({'Hospital Name':len}).sort('Hospital Name', ascending=False)
# Out:
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#              Hospital Name
# Provider ID
# 450388                  51
# 440049                  51
# 240004                  51
# 490009                  51
# 040118                  51
# 290001                  51
# 140053                  51
# 140276                  51
# 360068                  51
# 340126                  51
# 320001                  51
# 420043                  51
# 130006                  51
# 490021                  51
# 490022                  51
# 250001                  51
# 210049                  51
# 090004                  51
# 110095                  51
# 320018                  51
# 500024                  51
# 340115                  51
# 370093                  51
# 030065                  51
# 340113                  51
# 040020                  51
# ...

# %%
df_merge = df_hospitals.merge(df_effective, on='Provider ID')

# %%
df_merge.groupby('Hospital Type').agg({'Provider ID':len})
# Out:
#                                       Provider ID
# Hospital Type
# ACUTE CARE - VETERANS ADMINISTRATION         1548
# Acute Care Hospitals                       161549
# Childrens                                     846
# Critical Access Hospitals                   53878
